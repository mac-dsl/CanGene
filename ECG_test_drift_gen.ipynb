# %%
from util.stream import Stream, transform_stream
from util.drift_generator import DriftGenerator
import os
import yaml

# %% [markdown]
# ### Creating Drifts based on ECG

# %%
# Parse source filepaths from config (.yaml) file
with open('ECG_test.yaml') as f:
    config_param = yaml.load(f, Loader=yaml.FullLoader)

# source_dir = os.path.abspath(config_param['source_dir'])

selected_files = config_param['source_files']
dir = config_param['source_dir']
ECGStreams = []
for i, file in enumerate(selected_files):
    ECGStreams.append(Stream(f"{dir}/{file}"))
    ECGStreams[i].plot()
    # plt.savefig(f'temp{i}.png')
    print(ECGStreams[i].filename)
# Out:
# MBA_ECG801_data
# MBA_ECG803_data
# MBA_ECG805_data
# MBA_ECG806_data
# MBA_ECG820_data

# %%
for i, file in enumerate(selected_files):
    # ECGStreams.append(Stream(f"{dir}/{file}"))
    ECGStreams[i].plot(start=15000, end=20000)
    # plt.savefig(f'temp{i}.png')
    print(ECGStreams[i].filename)
# Out:
# MBA_ECG803_data
# MBA_ECG805_data
# MBA_ECG806_data

# %%
moa_path = config_param['moa_path']
source_streams = ECGStreams
drift_dir = os.getcwd()+ config_param['drift_dir']
g = DriftGenerator(dir, drift_dir, moa_path, selected_streams=source_streams)

length = ECGStreams[0].length
dataset = 'ECGTest_n_d'

n_drift = config_param['drift_params']['n_drift']
p_drift = config_param['drift_params']['p_drift']
p_before = config_param['drift_params']['p_before']
sub_dir = config_param['drift_params']['sub_dir']

for n_d in n_drift:
    ds = g.run_generate_grad_stream_moa(
        length=length,
        p_drift = 0.2,
        n_drift = n_d,
        p_before = p_before,
        sub_dir=sub_dir,
        dataset = dataset,
        mode=0        
    )

    # ds.plot_drift()
# Out:
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p19_n2_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 0.73s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p19_n2_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p19_n3_b33
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 0.73s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p19_n3_b33.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p19_n3_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 0.82s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p19_n3_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p19_n5_b40
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 0.85s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p19_n5_b40.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p19_n6_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.10s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p19_n6_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p19_n7_b42
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 0.93s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p19_n7_b42.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p19_n8_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.19s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p19_n8_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p19_n9_b44
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.12s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p19_n9_b44.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p19_n9_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.17s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p19_n9_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p19_n11_b45
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.28s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p19_n11_b45.arff
# Done!
# Generating drift labels...	Done!

# %%
n_d = 10
ds = g.run_generate_grad_stream_moa(
    length=length,
    p_drift = 0.1,
    n_drift = n_d,
    p_before = p_before,
    sub_dir=sub_dir,
    dataset = dataset,
    mode=0        
)

ds.plot_drift()
# Out:
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_n_d_grad_p9_n10_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.15s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_n_d_grad_p9_n10_b50.arff
# Done!
# Generating drift labels...	Done!

# %%
ds.plot_drift_k(k=5, w=3000)

# %%
p_before
# Out:
# 0.5

# %%
dataset = 'ECGTest_p_d'
for p_d in p_drift:
    ds = g.run_generate_grad_stream_moa(
        length=length,
        p_drift = p_d,
        n_drift = 10,
        p_before = p_before,
        sub_dir=sub_dir,
        dataset = dataset,
        mode=0        
    )

    ds.plot_drift()
# Out:
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_p_d_grad_p4_n10_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.21s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_p_d_grad_p4_n10_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_p_d_grad_p9_n10_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.21s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_p_d_grad_p9_n10_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_p_d_grad_p14_n10_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.24s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_p_d_grad_p14_n10_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_p_d_grad_p19_n9_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.05s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_p_d_grad_p19_n9_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_p_d_grad_p24_n10_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.20s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_p_d_grad_p24_n10_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_p_d_grad_p29_n10_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.13s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_p_d_grad_p29_n10_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_p_d_grad_p34_n10_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.11s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_p_d_grad_p34_n10_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_p_d_grad_p39_n10_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 1.09s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_p_d_grad_p39_n10_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_p_d_grad_p44_n9_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task completed in 0.95s (CPU time)
# Stream written to ARFF file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_p_d_grad_p44_n9_b50.arff
# Done!
# Generating drift labels...	Done!
# Generating splits...
# 	Getting partitions...
# 	Getting order of drifts coming before anomaly...
# 	Getting drift center positions...
# 	Getting stream file cuts...
# Done!
# Getting stream file cuts...	Done!
# Creating intermediate files...	Done!
# Recursively generating MOA command...	Done!
# Drift filename:  ECGTest_p_d_grad_p49_n10_b50
# Running terminal command...
# {M}assive {O}nline {A}nalysis
# Version:  23.04 April 2023
# Copyright: (C) 2007-2023 University of Waikato, Hamilton, New Zealand
# Web: http://moa.cms.waikato.ac.nz/
#
#
# Task failed. Reason:
# java.lang.RuntimeException: Failed writing to file /Users/jongjunPark/Research-timeSeries/qdb-demo/AnomalyDriftDetection/data/synthetic/test/ECGTest_p_d_grad_p49_n10_b50.arff
# 	at moa.tasks.WriteStreamToARFFFile.doMainTask(WriteStreamToARFFFile.java:86)
# 	at moa.tasks.MainTask.doTaskImpl(MainTask.java:50)
# 	at moa.tasks.AbstractTask.doTask(AbstractTask.java:57)
# 	at moa.tasks.TaskThread.run(TaskThread.java:76)
# Caused by: java.lang.NullPointerException
# 	at moa.tasks.WriteStreamToARFFFile.doMainTask(WriteStreamToARFFFile.java:80)
# 	... 3 more
# Done!
# Generating drift labels...	Done!
# ---------------------------------------------------------------------------
# BadDataFormat                             Traceback (most recent call last)
# Cell In[5], line 3
#       1 dataset = 'ECGTest_p_d'
#       2 for p_d in p_drift:
# ----> 3     ds = g.run_generate_grad_stream_moa(
#       4         length=length,
#       5         p_drift = p_d,
#       6         n_drift = 10,
#       7         p_before = p_before,
#       8         sub_dir=sub_dir,
#       9         dataset = dataset,
#      10         mode=0
#      11     )
#      13     ds.plot_drift()
#
# File ~/Research-timeSeries/qdb-demo/AnomalyDriftDetection/util/drift_generator.py:96, in DriftGenerator.run_generate_grad_stream_moa(self, length, p_drift, n_drift, p_before, sub_dir, dataset, mode)
#      90 print('Done!')
#      92 output_path = self.assemble_drift_stream(
#      93     positions, streams, w_drift, seq_before, sub_dir, length, dataset
#      94 )
# ---> 96 drift_stream = DriftStream(output_path, self.source_dir)
#      98 return drift_stream
#
# File ~/Research-timeSeries/qdb-demo/AnomalyDriftDetection/util/stream.py:246, in DriftStream.__init__(self, filepath, source_dir, colours)
#     245 def __init__(self, filepath, source_dir, colours=COLOURS):
# --> 246     super().__init__(filepath)
#     247     drift_params = self.__get_drift_params()
#     248     drift_labels = np.array(drift_params[0])
#
# File ~/Research-timeSeries/qdb-demo/AnomalyDriftDetection/util/stream.py:41, in Stream.__init__(self, filepath)
#      39     self.length = len(self.anomaly_labels)
#      40 elif file_ext == "arff":
# ---> 41     self.data, self.anomaly_labels = self.__get_arff_data_labels(filepath)
#      42     self.drift_labels = self.__get_drift_labels()
#      43     self.length = len(self.anomaly_labels)
#
# File ~/Research-timeSeries/qdb-demo/AnomalyDriftDetection/util/stream.py:199, in Stream.__get_arff_data_labels(self, filename)
#     195 def __get_arff_data_labels(self, filename: str):
#     196     """
#     197     Find ndarray corresponding to data and labels from arff data
#     198     """
# --> 199     arff_content = arff.load(f.replace(',\n', '\n') for f in open(filename, 'r'))
#     200     arff_data = arff_content['data']
#     201     data = np.array([i[:1] for i in arff_data])
#
# File /opt/miniconda3/envs/conda-drift/lib/python3.8/site-packages/arff.py:1059, in load(fp, encode_nominal, return_type)
#    1045 '''Load a file-like object containing the ARFF document and convert it into
#    1046 a Python object.
#    1047
#    (...)
#    1056 :return: a dictionary.
#    1057  '''
#    1058 decoder = ArffDecoder()
# -> 1059 return decoder.decode(fp, encode_nominal=encode_nominal,
#    1060                       return_type=return_type)
#
# File /opt/miniconda3/envs/conda-drift/lib/python3.8/site-packages/arff.py:896, in ArffDecoder.decode(self, s, encode_nominal, return_type)
#     894 except ArffException as e:
#     895     e.line = self._current_line
# --> 896     raise e
#
# File /opt/miniconda3/envs/conda-drift/lib/python3.8/site-packages/arff.py:892, in ArffDecoder.decode(self, s, encode_nominal, return_type)
#     877 '''Returns the Python representation of a given ARFF file.
#     878
#     879 When a file object is passed as an argument, this method reads lines
#    (...)
#     889     progressively`_.
#     890 '''
#     891 try:
# --> 892     return self._decode(s, encode_nominal=encode_nominal,
#     893                         matrix_type=return_type)
#     894 except ArffException as e:
#     895     e.line = self._current_line
#
# File /opt/miniconda3/envs/conda-drift/lib/python3.8/site-packages/arff.py:870, in ArffDecoder._decode(self, s, encode_nominal, matrix_type)
#     867             yield row
#     869 # Alter the data object
# --> 870 obj['data'] = data.decode_rows(stream(), self._conversors)
#     871 if obj['description'].endswith('\n'):
#     872     obj['description'] = obj['description'][:-1]
#
# File /opt/miniconda3/envs/conda-drift/lib/python3.8/site-packages/arff.py:519, in _DataListMixin.decode_rows(self, stream, conversors)
#     518 def decode_rows(self, stream, conversors):
# --> 519     return list(super(_DataListMixin, self).decode_rows(stream, conversors))
#
# File /opt/miniconda3/envs/conda-drift/lib/python3.8/site-packages/arff.py:470, in DenseGeneratorData.decode_rows(self, stream, conversors)
#     468 else:
#     469     if len(values) != len(conversors):
# --> 470         raise BadDataFormat(row)
#     472 yield self._decode_values(values, conversors)
#
# BadDataFormat: Bad @DATA instance format in line 202884: -0
